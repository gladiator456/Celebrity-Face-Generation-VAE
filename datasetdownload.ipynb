# %%
import os


os.environ['KAGGLE_USERNAME'] = "anujsaxena875"
os.environ['KAGGLE_KEY'] = "KGAT_61564fef03772b0c8803f55624b29c62"

print("API Token set ho gaya hai!")
# Out:
# API Token set ho gaya hai!

# %%
# Dataset download karo
# !kaggle datasets download -d jessicali9530/celeba-dataset

# File ko unzip karo
# !unzip -q celeba-dataset.zip -d ./celeba_data

print("Data Hunt Successful! 1.3GB data Google server par aa gaya hai.")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jessicali9530/celeba-dataset
# License(s): other
# ...
# 100% 1.33G/1.33G [00:08<00:00, 168MB/s]
#
# Data Hunt Successful! 1.3GB data Google server par aa gaya hai.
